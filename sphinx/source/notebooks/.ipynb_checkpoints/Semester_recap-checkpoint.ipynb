# %% [markdown]
# # Semester Recap

# %% [markdown]
# ## Strings
# * Top level syntax and build-in functions
# * String methods

# %% [markdown]
# ## Data Structures

# %% [markdown]
# # List Comprehensions

# %%
colors = ['Black', 'White']
sizes = ['s', 'm', 'l', 'xl']

# %%
[(c,s) for c in colors for s in sizes]
# Out:
# [('Black', 's'),
#  ('Black', 'm'),
#  ('Black', 'l'),
#  ('Black', 'xl'),
#  ('White', 's'),
#  ('White', 'm'),
#  ('White', 'l'),
#  ('White', 'xl')]

# %%
soled_out = [('Black', 'm'), ('White', 's')]

# %%
[(c,s) for c in colors for s in sizes if (c, s) not in soled_out]
# Out:
# [('Black', 's'),
#  ('Black', 'l'),
#  ('Black', 'xl'),
#  ('White', 'm'),
#  ('White', 'l'),
#  ('White', 'xl')]
